# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
# %matplotlib inline
plt.style.use('ggplot')

# %%
# Out:
# 1926881

# %%
frame.head(5)
# Out:
#    0  1  1502  1589  1629  1645  1665  1702  1766  1781  ...   2282  2287  \
# 0  1  1  1667   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN
# 1  2  1  1611   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN
# 2  3  1  1601   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN
# 3  4  1  1643   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN
# 4  5  1  1604   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN
#
#    2302  2326  2337  2382  2388  2390  2438  2948
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 47 columns]

# %%
frame.describe()
# Out:
#                     0               1           1502          1589  \
# count  1926881.000000  1926881.000000  162500.000000  67650.000000
# mean     67113.349104        3.882921    1910.673372   1966.747849
# std      41461.647534        2.443399      40.640690     80.804479
# min          1.000000        0.000000    1455.000000    773.000000
# 25%      32115.000000        1.000000    1886.000000   1908.000000
# 50%      64230.000000        4.000000    1905.000000   1968.000000
# 75%      98394.000000        7.000000    1935.000000   2013.000000
# max     166740.000000        7.000000    2356.000000   3684.000000
#
#                 1629           1645           1665           1702  \
# count  140900.000000  138000.000000  138000.000000  126800.000000
# mean     1904.962576    1917.807746    1922.385471    1950.632200
# std       112.082586     109.797258      97.500750      90.306356
# min         1.000000       2.000000       2.000000     972.000000
# ...

# %%
frame.corr()
# Out:
#              0         1      1502      1589      1629      1645      1665  \
# 0     1.000000  0.897134 -0.381112  0.305194  0.636669  0.674999 -0.449305
# 1     0.897134  1.000000 -0.495483  0.328419  0.660525  0.686457 -0.452859
# 1502 -0.381112 -0.495483  1.000000       NaN       NaN       NaN       NaN
# 1589  0.305194  0.328419       NaN  1.000000       NaN       NaN       NaN
# 1629  0.636669  0.660525       NaN       NaN  1.000000       NaN       NaN
# 1645  0.674999  0.686457       NaN       NaN       NaN  1.000000       NaN
# 1665 -0.449305 -0.452859       NaN       NaN       NaN       NaN  1.000000
# 1702 -0.695094 -0.661576       NaN       NaN       NaN       NaN       NaN
# 1766 -0.636670 -0.607981       NaN       NaN       NaN       NaN       NaN
# 1781  0.800094  0.810352       NaN       NaN       NaN       NaN       NaN
# 1820 -0.334073 -0.326833       NaN -0.232306       NaN       NaN       NaN
# ...

# %%
frame[frame./0 == 1].value_counts()
# Out:
#   File "<ipython-input-36-1402f00e0248>", line 1
#     frame[frame./0 == 1].value_counts()
#                 ^
# SyntaxError: invalid syntax
