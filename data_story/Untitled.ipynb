# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
# %matplotlib inline
plt.style.use('ggplot')

# %%
investor = pd.read_csv('./data/techcrunch.csv')
investor[:10]
# Out:
#           investor_permalink              investor_name  total  average_age  \
# 0               500-startups               500 Startups     74    30.065753
# 1             accel-partners             Accel Partners     38    31.550685
# 2        andreessen-horowitz        Andreessen Horowitz     30    30.728767
# 3              atlas-venture              Atlas Venture     13    32.167123
# 4                    atomico                    Atomico     15    35.860274
# 5          balderton-capital          Balderton Capital     17    32.624658
# 6          baseline-ventures          Baseline Ventures     18    30.479452
# 7           battery-ventures           Battery Ventures     11    34.961644
# 8                benchmark-2                  Benchmark     17    32.304110
# 9  bessemer-venture-partners  Bessemer Venture Partners     19    36.142466
#
#    under_20  t20  t30  t40  t50  t60
# 0         0   45   27    1    1    0
# 1         1   12   21    4    0    0
# ...

# %%
rounds = pd.read_csv('./data/crunchbase_rounds.csv')
rounds.dtypes
#print rounds.columns
# print rounds[rounds.company_city == 'San Francisco']

#print rounds('company_city')
#rounds.groupby('company_city').sum('company_category_list')
rounds.company_city.value_counts()
# Out:
# Bedford              9
# San Francisco        8
# Beijing              7
# Providence           6
# Paris                5
# New York             5
# Bellevue             4
# Woodbine             4
# Suzhou               3
# Los Angeles          3
# Chicago              2
# Melbourne            2
# Bra                  2
# Mountain View        2
# Lake Oswego          1
# Buenos Aires         1
# Timisoara            1
# Santa Monica         1
# Cleveland            1
# Champaign            1
# Connellys Springs    1
# London               1
# Shanghai             1
# Orlando              1
# Lexington            1
# Berlin               1
# Oakland Park         1
# Huntsville           1
# Cambridge            1
# West Hollywood       1
# Tallinn              1
# Sydney               1
# Lake Mary            1
# Stockholm            1
# Oakland              1
# Las Condes           1
# Guangzhou            1
# Vienna               1
# Iselin               1
# Seattle              1
# ...

# %%
frame.describe()
frame.columns
# Out:
# Index([u'acquired_at', u'acquired_month', u'acquired_quarter',
#        u'acquired_year', u'acquirer_category_list', u'acquirer_city',
#        u'acquirer_country_code', u'acquirer_market', u'acquirer_name',
#        u'acquirer_permalink', u'acquirer_region', u'acquirer_state_code',
#        u'average_age', u'category_code', u'city', u'company_category_list',
#        u'company_city', u'company_country_code', u'company_market',
#        u'company_name', u'company_permalink', u'company_region',
#        u'company_state_code', u'country_code', u'first_funding_at',
#        u'founded_at', u'founded_month', u'founded_quarter', u'founded_year',
#        u'funded_at', u'funded_month', u'funded_quarter', u'funded_year',
#        u'funding_round_code', u'funding_round_permalink',
#        u'funding_round_type', u'funding_rounds', u'funding_total_usd',
#        u'homepage_url', u'id', u'investor_category_list', u'investor_city',
# ...

# %%
#frame.company_state_code.value_counts()
rounds.columns
#frame[frame.company_city ==
# Out:
# Index([u'company_permalink', u'company_name', u'company_category_list',
#        u'company_market', u'company_country_code', u'company_state_code',
#        u'company_region', u'company_city', u'funding_round_permalink',
#        u'funding_round_type', u'funding_round_code', u'funded_at',
#        u'funded_month', u'funded_quarter', u'funded_year',
#        u'raised_amount_usd'],
#       dtype='object')

# %%
company_by_state = rounds.groupby(['company_city','company_market','raised_amount_usd']).agg([np.median,max,min])
company_by_state.stack().head(5)
# Out:
#                                                       funded_year
# company_city company_market raised_amount_usd
# Bedford      Manufacturing  12,400,000        median         2008
#                                               max            2008
#                                               min            2008
#                             15,000,000        median         2013
#                                               max            2013

# %%
investments = pd.read_csv('./data/crunchbase_investments.csv')
investments.columns
# Out:
# Index([u'company_permalink', u'company_name', u'company_category_list',
#        u'company_market', u'company_country_code', u'company_state_code',
#        u'company_region', u'company_city', u'investor_permalink',
#        u'investor_name', u'investor_category_list', u'investor_market',
#        u'investor_country_code', u'investor_state_code', u'investor_region',
#        u'investor_city', u'funding_round_permalink', u'funding_round_type',
#        u'funding_round_code', u'funded_at', u'funded_month', u'funded_quarter',
#        u'funded_year', u'raised_amount_usd'],
#       dtype='object')

# %%
companies = pd.read_csv('./data/crunchbase_companies.csv')
companies.columns
# Out:
# Index([u'permalink', u'name', u'homepage_url', u'category_code',
#        u'funding_total_usd', u'status', u'country_code', u'state_code',
#        u'region', u'city', u'funding_rounds', u'founded_at', u'founded_month',
#        u'founded_quarter', u'founded_year', u'first_funding_at',
#        u'last_funding_at', u'last_milestone_at', u'id'],
#       dtype='object')

# %%
acquistions = pd.read_csv('./data/crunchbase_acquisitions.csv')
acquistions.sort('price_amount')
#acquistions.sort('acquired_year').head(20)

list={}
for comp in acquistions:
    if (acquistions[comp]price_amount) != 'NaN':
        list.append
print list
# Out:
#   File "<ipython-input-77-8784a7de6291>", line 7
#     if (acquistions[comp]price_amount) != 'NaN':
#                                     ^
# SyntaxError: invalid syntax

# %%
#perform an inner join from the data above
merged_roundsinvestments = pd.merge(left=rounds,right=investments, left_on = 'company_name', right_on'company_name')
merged_roundsinvestments.shape
# Out:
#   File "<ipython-input-36-2f175ebf7af9>", line 2
#     merged_roundsinvestments = pd.merge(left=rounds,right=investments, left_on = 'company_name', right_on'company_name')
#                                                                                                                       ^
# SyntaxError: invalid syntax

# %%
frame
# Out:
#             acquired_at acquired_month acquired_quarter  acquired_year  \
# 0   2013-10-17T00:00:00        2013-10          2013-Q4           2013
# 1   2008-09-16T00:00:00        2008-09          2008-Q3           2008
# 2   2014-05-08T00:00:00        2014-05          2014-Q2           2014
# 3   2014-03-20T00:00:00        2014-03          2014-Q1           2014
# 4   2011-01-01T00:00:00        2011-01          2011-Q1           2011
# 5   2012-07-23T00:00:00        2012-07          2012-Q3           2012
# 6   2012-02-02T00:00:00        2012-02          2012-Q1           2012
# 7   2006-01-01T00:00:00        2006-01          2006-Q1           2006
# 8   2014-01-07T00:00:00        2014-01          2014-Q1           2014
# 9   2012-09-22T00:00:00        2012-09          2012-Q3           2012
# 10  2012-10-03T00:00:00        2012-10          2012-Q4           2012
# 11  2013-02-27T00:00:00        2013-02          2013-Q1           2013
# ...
